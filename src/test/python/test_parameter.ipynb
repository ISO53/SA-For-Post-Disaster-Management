    [0.7442, 0.7382, 0.7458, 0.7448, 0.7448, 0.7439, 0.7436, 0.7458, 0.7459, 0.7421, 0.7412, 0.7413, 0.7430, 0.7392, 0.7450, 0.7456, 0.7451, 0.7402, 0.7434],	
    [0.7431, 0.7457, 0.7437, 0.7435, 0.7464, 0.7461, 0.7391, 0.7434, 0.7449, 0.7458, 0.7452, 0.7460, 0.7452, 0.7424, 0.7449, 0.7432, 0.7428, 0.7432, 0.7461],	
    [0.7451, 0.7431, 0.7444, 0.7445, 0.7456, 0.7437, 0.7417, 0.7446, 0.7426, 0.7428, 0.7419, 0.7400, 0.7440, 0.7425, 0.7436, 0.7399, 0.7439, 0.7419, 0.7425],	
    [0.7437, 0.7457, 0.7429, 0.7463, 0.7431, 0.7465, 0.7459, 0.7435, 0.7440, 0.7454, 0.7439, 0.7420, 0.7437, 0.7426, 0.7438, 0.7463, 0.7431, 0.7429, 0.7438],	
    [0.7441, 0.7415, 0.7469, 0.7436, 0.7428, 0.7413, 0.7435, 0.7459, 0.7435, 0.7439, 0.7436, 0.7426, 0.7412, 0.7437, 0.7454, 0.7428, 0.7448, 0.7431, 0.7440],	
    [0.7435, 0.7435, 0.7462, 0.7444, 0.7460, 0.7387, 0.7433, 0.7441, 0.7435, 0.7464, 0.7425, 0.7434, 0.7466, 0.7427, 0.7455, 0.7419, 0.7456, 0.7449, 0.7443],	
    [0.7391, 0.7432, 0.7458, 0.7439, 0.7450, 0.7466, 0.7422, 0.7452, 0.7452, 0.7397, 0.7456, 0.7413, 0.7421, 0.7453, 0.7438, 0.7448, 0.7429, 0.7423, 0.7412],	
    [0.7437, 0.7433, 0.7431, 0.7427, 0.7436, 0.7404, 0.7441, 0.7451, 0.7419, 0.7442, 0.7450, 0.7444, 0.7454, 0.7454, 0.7432, 0.7453, 0.7432, 0.7437, 0.7451]
]	

# Define temperature and cooling rate values
cooling_rates = [0.0500, 0.1000, 0.1500, 0.2000, 0.2500, 0.3000, 0.3500, 0.4000, 0.4500, 0.5000, 0.5500, 0.6000, 0.6500, 0.7000, 0.7500, 0.8000, 0.8500, 0.9000, 0.9500]
temperatures = [5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000]

# %%
# Create a meshgrid for temperature and cooling rate values
T, CR = np.meshgrid(temperatures, cooling_rates)

# Create the contour plot
plt.contourf(T, CR, fitness_matrix, cmap='inferno')
plt.colorbar(label='Fitness')  # Add color bar with label

# Set labels for axes
plt.xlabel('Temperature')
plt.ylabel('Cooling Rate')

# Show the plot
plt.show()

# %%
best_temperature, best_cooling_rate, best_fitness = 0, 0, 99999

for i, fitnesses in enumerate(fitness_matrix):
    for j, fitness in enumerate(fitnesses):
        if fitness < best_fitness:
            best_fitness = fitness
            best_temperature = i
            best_cooling_rate = j

print('fitness:', temperatures[best_temperature], cooling_rates[best_cooling_rate], best_fitness)
# Out:
# fitness: 60000 0.1 0.7382

# %%
# Read the CSV file
data = pd.read_csv("C:/Users/termi/Documents/Projects/SchoolProjects/SA-For-Post-Disaster-Management/src/test/python/mutation_data.csv", delimiter=',')

# Extracting the columns
insert = data['Insert']
inversion = data['Inversion']
scramble = data['Scramble']
swap = data['Swap']

# Creating x-axis values for each mutation algorithm
x_values = np.arange(len(inversion))

# Plotting the dot graph
plt.figure(figsize=(10, 6))
plt.scatter(x_values, inversion, label='Inversion', color='blue')
plt.scatter(x_values, scramble, label='Scramble', color='orange')
plt.scatter(x_values, swap, label='Swap', color='green')
plt.scatter(x_values, swap, label='Insert', color='red')

# Adding labels and title
plt.title('Fitness Values for Simulated Annealing with Different Mutation Algorithms')
plt.xlabel('Iterations')
plt.ylabel('Fitness Value')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # VERSION 2

# %%
0.8911, 0.8917, 0.8924, 0.8902, 0.8928, 0.8925, 0.8933, 0.8931, 0.8922, 0.8922, 0.8915, 0.8925, 0.8920, 0.8922, 0.8926, 0.8919, 0.8923, 0.8912, 0.8914,
0.8932, 0.8918, 0.8919, 0.8908, 0.8929, 0.8916, 0.8920, 0.8926, 0.8912, 0.8911, 0.8931, 0.8929, 0.8925, 0.8919, 0.8922, 0.8928, 0.8926, 0.8927, 0.8921,
0.8924, 0.8922, 0.8917, 0.8915, 0.8913, 0.8925, 0.8909, 0.8935, 0.8918, 0.8911, 0.8925, 0.8917, 0.8929, 0.8917, 0.8920, 0.8925, 0.8918, 0.8920, 0.8920,
0.8919, 0.8930, 0.8918, 0.8921, 0.8926, 0.8922, 0.8919, 0.8916, 0.8928, 0.8926, 0.8923, 0.8934, 0.8921, 0.8927, 0.8926, 0.8929, 0.8924, 0.8931, 0.8927,
0.8925, 0.8911, 0.8923, 0.8920, 0.8925, 0.8922, 0.8922, 0.8923, 0.8934, 0.8918, 0.8930, 0.8931, 0.8924, 0.8917, 0.8927, 0.8921, 0.8922, 0.8908, 0.8919,
0.8914, 0.8905, 0.8925, 0.8924, 0.8917, 0.8919, 0.8927, 0.8925, 0.8927, 0.8920, 0.8921, 0.8927, 0.8927, 0.8913, 0.8929, 0.8914, 0.8921, 0.8928, 0.8914,
0.8926, 0.8918, 0.8927, 0.8924, 0.8922, 0.8926, 0.8931, 0.8918, 0.8919, 0.8925, 0.8930, 0.8927, 0.8916, 0.8925, 0.8930, 0.8917, 0.8922, 0.8919, 0.8923,
0.8916, 0.8925, 0.8927, 0.8923, 0.8920, 0.8927, 0.8920, 0.8910, 0.8914, 0.8931, 0.8927, 0.8921, 0.8924, 0.8923, 0.8921, 0.8911, 0.8897, 0.8912, 0.8925,
